# %%
# mount the drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/My Drive/NLP/Project/Turkish

# %%
import os
os.chdir('./drive/MyDrive/NLP/Project/Turkish')
# !ls
# Out:
# data	    turkish_main_harish.ipynb  utilities
# embeddings  turkish_main.ipynb	       w2v_gnews_small.txt
# main.ipynb  turkish_main_old.ipynb

# %%
from __future__ import print_function, division
# %matplotlib inline
from matplotlib import pyplot as plt
import json
import random
import numpy as np
import json
import os
from utilities.word_embeddings import WordEmbedding
from utilities.plots import *

# %% [markdown]
# ### 1: Gender Bias in Word Embedding
#
# ### Data
# January-December 2018 Commoncrawl
# ### Load data
# Load the word embedding. The embedding maps each word into a 300-dimension vector.

# %%
def load_professions():
    '''
       load data from profession.json 
    '''
    professions_file = os.path.join('./data', 'professions.json')
    with open(professions_file, 'r') as f:
        professions = json.load(f)
    # print('Loaded professions\n' +
    #       'Format:\n' +
    #       'word,\n' +
    #       'definitional female -1.0 -> definitional male 1.0\n' +
    #       'stereotypical female -1.0 -> stereotypical male 1.0')
    return professions

# %%
# load turkish Glove
E = WordEmbedding()
E.load_embeddings('./embeddings/turkish_vectors.txt')

# load professions
professions = load_professions()
profession_words = [p[0] for p in professions]
# Out:
# (253832, 300)

# %% [markdown]
# ### 2: Define gender direction
#
# We have used Woman - Man here to get the gender direction in the vector space.

# %%
v_gender = E.diff('kadını', 'adam')

# %% [markdown]
# ### Corpus and vocab size is very large. Taking a subset of the vocab to calculate the score.
#
# #### Generate analogies

# %%
a_gender = E.get_analogy_based_thresh(v_gender,max_words=30000)
# Out:
# Computing neighbors

# %%
she_occupation = ['homemaker', 'nurse', 'receptionist', 'librarian', 'socialite', 'hairdresser', 
'nanny', 'bookkeeper', 'stylist', 'housekeeper', 'designer', 'sewing']

# she_occupation_turkish = []

# %% [markdown]
# ### Normal install of googletrans didn't work, had to install alpha version.
# https://stackoverflow.com/questions/52455774/googletrans-stopped-working-with-error-nonetype-object-has-no-attribute-group

# %%
#!pip install googletrans==3.1.0a0

# %%
from googletrans import Translator
translator = Translator()

# %% [markdown]
# ### Helper Function to translate words from source language to target language

# %%
def get_translation(src_list,src_lang, tgt_lang):
  return [item.text for item in translator.translate(src_list, src=src_lang, dest=tgt_lang)]

  # for item in src_list:
  #   target = translator.translate(item, src=src_lang, dest=tgt_lang).text
  #   target_list.append(target)
  # return target_list

# %%
she_occupation_turkish = get_translation(she_occupation, 'en', 'tr')

# %%
for en, tr in zip(she_occupation, she_occupation_turkish):
  print(en, '\t\t\t', tr)
# Out:
# homemaker 			 ev hanımı
# nurse 			 hemşire
# receptionist 			 resepsiyonist
# librarian 			 kütüphaneci
# socialite 			 sosyetik
# hairdresser 			 kuaför
# nanny 			 dadı
# bookkeeper 			 muhasebeci
# stylist 			 stilist
# housekeeper 			 kahya
# designer 			 tasarımcı
# sewing 			 dikiş

# %%
E.word2index['kadını']
# Out:
# 3310

# %%
counter = 1
for (a,b,c) in a_gender:
    a,b = get_translation([a,b], 'tr', 'en')
    # if a in she_occupation_turkish:
    print(a+"-"+b+"-"+str(c))
    counter += 1 
    if counter > 50:
      break
# Out:
# woman-man-1.0
# woman's-your man-0.72630006
# to the woman-to the man-0.62636423
# with woman-with the man-0.5674051
# is a woman-is the man-0.5071459
# from woman-from the man-0.48661
# women-people-0.4651298
# women-peoples-0.45814937
# Hatice-Ali-0.44985628
# lady-handsome-0.4485165
# fatma-Hasan-0.44597846
# older sister-brother-0.43073273
# woman-gentleman-0.43001527
# eminem-Ahmet-0.4250175
# my cinema-tolga-0.41986892
# daughter-son--0.4099087
# our women-our youth-0.40680158
# auntie-uncle-0.40375972
# women-youth-0.40034848
# my daughter-my son-0.40021813
# wife-his father-0.39926654
# to women-to children-0.39407244
# betül-Hakan-0.39406663
# from women-from people-0.3895776
# to the lady-gentleman-0.38849005
# lady-gentleman-0.38553262
# Lady-Mr-0.37853307
# with women-with people-0.37557966
# woman-youth-0.3752285
# you are right-huh-0.37075862
# dear-mate-0.3707531
# my partner-my father-0.3687628
# actress-player-0.36851406
# tugba-serdar-0.36611634
# my older sister-my brother-0.36140114
# ayse-Mehmet-0.3581946
# ladies-guys-0.3567136
# Esra-murat-0.35497808
# marie-paul-0.3544483
# Gulshan-gokhan-0.3539269
# aysegul-alper-0.35181612
# akgun-aykut-0.35143557
# man's-man's-0.3501503
# song-serkan-0.348962
# daughters-brother-0.3483439
# they do-men-0.34815866
# zodiac sign-Lion-0.34605595
# our women-our youth-0.34585297
# Emma-tom-0.34286076
# in woman-in humans-0.3413243

# %% [markdown]
# ### Translate English profession words to Turkish

# %%
profession_words_turkish = get_translation(profession_words, 'en', 'tr')

# %%
profession_words_turkish[:10]
# Out:
# ['Muhasebeci',
#  'tanıdık',
#  'aktör',
#  'aktris',
#  'yardımcı profesör',
#  'yönetici',
#  'maceracı',
#  'avukat',
#  'yardımcı',
#  'meclis üyesi']

# %% [markdown]
# ### Get embeddings, Handle exception for those words which are not part of the corpus

# %%
def get_embed(word):
  try:
    return E.embeddings[E.word2index[word]]
  except KeyError:
    return -1

# %% [markdown]
# ### Check the gender bias

# %%
# sp = sorted([(E.get_embedding(w).dot(v_gender), w) for w in profession_words_turkish])
sp = []
counter = 0 
for word in profession_words_turkish:
  sim = get_embed(word)
  if isinstance(sim, int):
    # print('word not found: ', word)
    counter +=1 
  else:
    sp.append((sim.dot(v_gender), word))

sp = sorted(sp)
she_words = get_translation([item[1] for item in sp[-20:]], 'tr', 'en')
he_words = get_translation([item[1] for item in sp[0:20]], 'tr', 'en')

she_words_biased = []
for item1, item2 in zip(she_words, sp[-20:]):
  she_words_biased.append((item2[0], item1))

he_words_biased = []
for item1, item2 in zip(he_words, sp[0:20]):
  he_words_biased.append((item2[0], item1))

# %%
he_words_biased, she_words_biased
# Out:
# ([(-0.3073244, 'captain'),
#   (-0.29770383, 'footballer'),
#   (-0.26647973, 'goalkeeper'),
#   (-0.25781387, 'expert'),
#   (-0.23311262, 'comic'),
#   (-0.2084247, 'priest'),
#   (-0.2084247, 'priest'),
#   (-0.20444761, 'professor'),
#   (-0.20327556, 'barman'),
#   (-0.19126175, 'waiter'),
#   (-0.18704021, 'drummer'),
#   (-0.186668, 'Barber'),
#   (-0.17856857, 'priest'),
#   (-0.16835871, 'baron'),
#   (-0.16476232, 'publisher'),
#   (-0.16437355, 'guitarist'),
#   (-0.16165839, 'character'),
#   (-0.15930623, 'saint'),
#   (-0.15440187, 'commander'),
#   (-0.15283114, 'Wizard')],
#  [(0.052056678, 'chancellor'),
#   (0.054406717, 'protester'),
#   (0.05445776, 'therapist'),
#   (0.05790152, 'pharmacist'),
#   (0.05790152, 'pharmacist'),
#   (0.060864702, 'nurse'),
#   (0.06286584, 'dermatologist'),
#   (0.063052334, 'psychologist'),
#   (0.06487394, 'sociologist'),
#   (0.06895921, 'supporter'),
#   (0.083951324, 'nanny'),
#   (0.084616005, 'ballerina'),
#   (0.08489738, 'ranger'),
#   (0.08680769, 'entrepreneur'),
#   (0.10557736, 'whore'),
#   (0.114532135, 'socialite'),
#   (0.13487989, 'stylist'),
#   (0.14444123, 'actress'),
#   (0.15283374, 'laborer'),
#   (0.15514469, 'hot')])

# %% [markdown]
# ### Analysis of Gender Bias in Profession
# * He professions are on the negative side of x-axis
# * She professions are on the positive side of x-axis

# %%
plot_words_extreme(he_words_biased, she_words_biased, 40, x_title='Word Extremes', y_title='Similarity', 
title='Gender Bias In Profession')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="55d5f2e3-478d-43ee-9f40-22a83e953a5d" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55d5f2e3-478d-43ee-9f40-22a83e953a5d")) {                    Plotly.newPlot(                        "55d5f2e3-478d-43ee-9f40-22a83e953a5d",                        [{"mode":"markers+text","name":"Markers and Text","text":["captain","footballer","goalkeeper","expert","comic","priest","priest","professor","barman","waiter","drummer","Barber","priest","baron","publisher","guitarist","character","saint","commander","Wizard","chancellor","protester","therapist","pharmacist","pharmacist","nurse","dermatologist","psychologist","sociologist","supporter","nanny","ballerina","ranger","entrepreneur","whore","socialite","stylist","actress","laborer","hot"],"textposition":"bottom center","x":[-1.0,-0.9487179487179487,-0.8974358974358975,-0.8461538461538461,-0.7948717948717949,-0.7435897435897436,-0.6923076923076923,-0.641025641025641,-0.5897435897435898,-0.5384615384615385,-0.4871794871794872,-0.4358974358974359,-0.3846153846153846,-0.33333333333333337,-0.28205128205128205,-0.23076923076923084,-0.17948717948717952,-0.1282051282051282,-0.07692307692307698,-0.02564102564102566,0.02564102564102555,0.07692307692307687,0.1282051282051282,0.17948717948717952,0.23076923076923084,0.28205128205128194,0.33333333333333326,0.3846153846153846,0.4358974358974359,0.4871794871794872,0.5384615384615383,0.5897435897435896,0.641025641025641,0.6923076923076923,0.7435897435897436,0.7948717948717947,0.846153846153846,0.8974358974358974,0.9487179487179487,1.0],"y":[-0.3073244094848633,-0.2977038323879242,-0.2664797306060791,-0.25781387090682983,-0.2331126183271408,-0.20842470228672028,-0.20842470228672028,-0.20444761216640472,-0.20327556133270264,-0.19126175343990326,-0.18704020977020264,-0.18666799366474152,-0.17856857180595398,-0.168358713388443,-0.16476231813430786,-0.16437354683876038,-0.1616583913564682,-0.15930622816085815,-0.15440186858177185,-0.15283113718032837,0.052056677639484406,0.05440671741962433,0.054457761347293854,0.057901520282030106,0.057901520282030106,0.06086470186710358,0.06286583840847015,0.06305233389139175,0.06487394124269485,0.06895920634269714,0.08395132422447205,0.08461600542068481,0.08489737659692764,0.08680769056081772,0.10557735711336136,0.11453213542699814,0.13487988710403442,0.14444123208522797,0.1528337448835373,0.15514469146728516],"type":"scatter"}],                        {"height":1000,"title":{"text":"Gender Bias In Profession","x":0.5},"width":1000,"xaxis":{"title":{"text":"Word Extremes"}},"yaxis":{"title":{"text":"Similarity"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %% [markdown]
# ![tr_biased.png](data:image/png;base64,...)

# %% [markdown]
# ### Professions on Male side of the axis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Professions on Female side of the axis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Debiasing Algorithms
#
# ###Debiasing the gender bias from Turkish embeddings
#
# ####Step 1: - Identify the gender subspace
#
# In this we are following the paper's implemented definitional pairs for Identifying the gender subspace in Turkish language after that PCA is used to reduce the dimensionality and to achieve the principal component.
#
# ####Step 2 : - Hard de-biasing (neutralize and equalize)
#
# Neutralize ensures that gender neutral words are zero in the gender subspace which we are getting by the help of "drop" function implemented below.
#
# Equalize is used to perfectly equalizes the sets of words which are outside the gender subspace and enforces that all the neurtral words are equidistant to the words in equality set, which is implemented in "debias_embeddings" function.

# %%
from sklearn.decomposition import PCA

def find_direction(pairs, num_components = 10):
    '''
        Identify the gender subspace
    '''
    matrix = []
    counter = 0 
    for a, b in pairs:
        emb = get_embed(a) 
        if not isinstance(emb, int):
          center = (get_embed(a) + get_embed(b))/2
          matrix.append(get_embed(a) - center)
          matrix.append(get_embed(b) - center)
        else:
          counter += 1 
    
    print("Pairs dropped: ", len(pairs) - counter)
    matrix = np.array(matrix)
    pca = PCA(n_components = num_components)
    pca.fit(matrix)
    # bar(range(num_components), pca.explained_variance_ratio_)
    return pca


def drop(u, v):
    '''
        Align the words such that they are equidistant from 
        gender specific words
    '''
    return u - v * u.dot(v) / v.dot(v)

def debias_embeddings(E, gender_specific_words, definitional, equalize):
    '''
        Find gender direction and do hard debiasing.
    '''
    gender_direction = find_direction(definitional,num_components=12).components_[0]
    specific_set = set(gender_specific_words)
    for i, w in enumerate(E.words):
        if w not in specific_set:
            E.embeddings[i] = drop(E.embeddings[i], gender_direction)
            # Neutralize the gender neutral words in gender subspace
    E.normalize()
    candidates = {x for e1, e2 in equalize for x in [(e1.lower(), e2.lower()),
                                                     (e1.title(), e2.title()),
                                                     (e1.upper(), e2.upper())]}
    print(candidates)
    for (a, b) in candidates:
        if (a in E.word2index and b in E.word2index):
            y = drop((E.get_embedding(a) + E.get_embedding(b)) / 2, gender_direction)
            z = np.sqrt(1 - np.linalg.norm(y)**2)
            if (E.get_embedding(a) - E.get_embedding(b)).dot(gender_direction) < 0:
                z = -z
            E.embeddings[E.word2index[a]] = z * gender_direction + y
            E.embeddings[E.word2index[b]] = -z * gender_direction + y
    E.normalize()
    # visualization of the turkish embeddings after debiasing algorithms
    candidates_tr = []
    mdict = dict(candidates)
    resultList = [[key, value] for key, value in mdict.items()]
    for item in resultList:
        candidates_tr.append(get_translation(item, 'tr', 'en'))
    print("In English--> ", candidates_tr)

# %% [markdown]
# ### Translate Definitional, Equalize and Gender Specific words in Turkish Language
#
# Here Google Translator is used to translate Definitional, Equalize and Gender Specific words in Turkish Language in order to make the embeddings available to the debiasing algorithms

# %%
# words used to identify the gender subspace
with open('./data/definitional_pairs.json', "r") as f:
    defs = json.load(f)
# print(len(defs), defs)
# words used to identify the gender subspace in turkish
defs_tr = []
for item in defs:
     defs_tr.append(get_translation(item, 'en', 'tr'))
print("Definitional ->", defs_tr)

##Equalize and Neutralize
# Equalize pairs ensure that neutral words are equidistant from both extremes 
with open('./data/equalize_pairs.json', "r") as f:
    equalize_pairs = json.load(f)
# print(equalize_pairs)
# Equalize pairs ensure that neutral words are equidistant from both extremes 
# in Turkish
equalize_pairs_tr = []
for item in equalize_pairs:
     equalize_pairs_tr.append(get_translation(item, 'en', 'tr'))
print("Equalized Pairs ->",equalize_pairs_tr)



# words where gender specificity is desired
with open('./data/gender_specific_seed.json', "r") as f:
    gender_specific_words = json.load(f)
# print("gender specific", len(gender_specific_words), gender_specific_words[:10])
# words where gender specificity is desired in turskish 
gender_specific_words_tr = []
gender_specific_words_tr = get_translation(gender_specific_words, 'en', 'tr')
print("Gender specific in turkish", gender_specific_words_tr[:10])
# Out:
# Definitional -> [['Kadın', 'adam'], ['kız', 'oğlan'], ['o', 'o'], ['anne', 'baba'], ['kız evlat', 'oğul'], ['gal', 'insan'], ['dişi', 'erkek'], ['o', 'onun'], ['kendini', 'kendisi'], ['Mary', 'John']]
# Equalized Pairs -> [['manastır', 'manastır'], ['sözcü', 'sözcü'], ['Katolik_rahip', 'rahibe'], ['Baba', 'Anne'], ['Erkekler', 'Kadın'], ['meclis üyesi', 'meclis üyesi'], ['büyükbaba', 'büyükanne'], ['torunlar', 'torunlar'], ['prostat kanseri', 'Yumurtalık kanseri'], ['testosteron', 'estrojen'], ['amca dayı', 'hala'], ['eşler', 'kocalar'], ['Baba', 'Anne'], ['büyükbaba', 'büyükanne'], ['O', 'O'], ['oğlan', 'kız'], ['erkek çocuklar', 'kızlar'], ['Erkek kardeş', 'kardeş'], ['Kardeşler', 'kız kardeşler'], ['işadamı', 'iş kadını'], ['başkan', 'başkan'], ['tay', 'kısrak'], ['kongre üyesi', 'kongre üyesi'], ['baba', 'anne'], ['babalar', 'anneler'], ['ahbaplar', 'kızlar'], ['eski kız arkadaşı', 'eski erkek arkadaş'], ['baba', 'anne'], ['babalık', 'annelik'], ['babalar', 'anneler'], ['dostum', 'büyükanne'], ['kardeşlik', 'kız öğrenci yurdu'], ['iğdiş edilmiş', 'kısrak'], ['beyefendi', 'Hanım'], ['beyler', 'Hanımlar'], ['Büyük baba', 'Nene'], ['erkek torun', 'kız torun'], ['o', 'o'], ['kendisi', 'kendini'], ['onun', 'o'], ['kral', 'kraliçe'], ['krallar', 'kraliçeler'], ['erkek', 'dişi'], ['erkekler', 'dişiler'], ['adam', 'Kadın'], ['erkekler', 'kadın'], ['erkek yeğen', 'yeğen'], ['prens', 'prenses'], ['okul çocuğu', 'okul kızı'], ['oğul', 'kız evlat'], ['oğulları', 'kız çocukları'], ['ikiz kardeş', 'ikiz kardeş']]
# Gender specific in turkish ['aktris', 'aktrisler', 'hala', 'teyzeler', 'Lisans', 'balerin', 'Berber dükkanı', 'bariton', 'sakal', 'sakal']

# %%
debias_embeddings(E, gender_specific_words_tr, defs_tr, equalize_pairs_tr)
# Out:
# Pairs dropped:  7
# {('prens', 'prenses'), ('KONGRE ÜYESI', 'KONGRE ÜYESI'), ('ERKEK TORUN', 'KIZ TORUN'), ('O', 'O'), ('Erkek', 'Dişi'), ('manastır', 'manastır'), ('Erkek Kardeş', 'Kardeş'), ('AMCA DAYI', 'HALA'), ('Onun', 'O'), ('meclis üyesi', 'meclis üyesi'), ('Erkekler', 'Dişiler'), ('TORUNLAR', 'TORUNLAR'), ('adam', 'kadın'), ('Işadamı', 'Iş Kadını'), ('kral', 'kraliçe'), ('kardeşlik', 'kız öğrenci yurdu'), ('Meclis Üyesi', 'Meclis Üyesi'), ('ahbaplar', 'kızlar'), ('ERKEK KARDEŞ', 'KARDEŞ'), ('tay', 'kısrak'), ('Büyükbaba', 'Büyükanne'), ('kendisi', 'kendini'), ('testosteron', 'estrojen'), ('Katolik_Rahip', 'Rahibe'), ('AHBAPLAR', 'KIZLAR'), ('erkek torun', 'kız torun'), ('Testosteron', 'Estrojen'), ('erkek çocuklar', 'kızlar'), ('ikiz kardeş', 'ikiz kardeş'), ('Erkek Çocuklar', 'Kızlar'), ('beyler', 'hanımlar'), ('BÜYÜKBABA', 'BÜYÜKANNE'), ('erkek yeğen', 'yeğen'), ('başkan', 'başkan'), ('Beyefendi', 'Hanım'), ('Kendisi', 'Kendini'), ('DOSTUM', 'BÜYÜKANNE'), ('Babalar', 'Anneler'), ('prostat kanseri', 'yumurtalık kanseri'), ('sözcü', 'sözcü'), ('büyük baba', 'nene'), ('erkek kardeş', 'kardeş'), ('Erkek Yeğen', 'Yeğen'), ('Kardeşler', 'Kız Kardeşler'), ('PROSTAT KANSERI', 'YUMURTALIK KANSERI'), ('BÜYÜK BABA', 'NENE'), ('BABA', 'ANNE'), ('babalar', 'anneler'), ('Eşler', 'Kocalar'), ('krallar', 'kraliçeler'), ('katolik_rahip', 'rahibe'), ('Oğlan', 'Kız'), ('Büyük Baba', 'Nene'), ('ERKEKLER', 'DIŞILER'), ('Okul Çocuğu', 'Okul Kızı'), ('KRALLAR', 'KRALIÇELER'), ('eşler', 'kocalar'), ('büyükbaba', 'büyükanne'), ('oğul', 'kız evlat'), ('Ahbaplar', 'Kızlar'), ('PRENS', 'PRENSES'), ('Krallar', 'Kraliçeler'), ('Prens', 'Prenses'), ('Başkan', 'Başkan'), ('BABALIK', 'ANNELIK'), ('eski kız arkadaşı', 'eski erkek arkadaş'), ('kardeşler', 'kız kardeşler'), ('ERKEK ÇOCUKLAR', 'KIZLAR'), ('BEYEFENDI', 'HANIM'), ('ESKI KIZ ARKADAŞI', 'ESKI ERKEK ARKADAŞ'), ('dostum', 'büyükanne'), ('Erkek Torun', 'Kız Torun'), ('KARDEŞLIK', 'KIZ ÖĞRENCI YURDU'), ('IKIZ KARDEŞ', 'IKIZ KARDEŞ'), ('Oğulları', 'Kız Çocukları'), ('beyefendi', 'hanım'), ('Adam', 'Kadın'), ('Babalık', 'Annelik'), ('Sözcü', 'Sözcü'), ('Tay', 'Kısrak'), ('BABALAR', 'ANNELER'), ('oğlan', 'kız'), ('EŞLER', 'KOCALAR'), ('ERKEK', 'DIŞI'), ('Baba', 'Anne'), ('BAŞKAN', 'BAŞKAN'), ('iğdiş edilmiş', 'kısrak'), ('Kardeşlik', 'Kız Öğrenci Yurdu'), ('MANASTIR', 'MANASTIR'), ('Prostat Kanseri', 'Yumurtalık Kanseri'), ('ERKEK YEĞEN', 'YEĞEN'), ('Ikiz Kardeş', 'Ikiz Kardeş'), ('Torunlar', 'Torunlar'), ('KARDEŞLER', 'KIZ KARDEŞLER'), ('TAY', 'KISRAK'), ('erkekler', 'dişiler'), ('IŞADAMI', 'IŞ KADINI'), ('Dostum', 'Büyükanne'), ('Iğdiş Edilmiş', 'Kısrak'), ('Kral', 'Kraliçe'), ('ERKEKLER', 'KADIN'), ('erkekler', 'kadın'), ('ADAM', 'KADIN'), ('ONUN', 'O'), ('Erkekler', 'Kadın'), ('torunlar', 'torunlar'), ('Amca Dayı', 'Hala'), ('Kongre Üyesi', 'Kongre Üyesi'), ('OKUL ÇOCUĞU', 'OKUL KIZI'), ('BEYLER', 'HANIMLAR'), ('babalık', 'annelik'), ('erkek', 'dişi'), ('OĞLAN', 'KIZ'), ('KENDISI', 'KENDINI'), ('işadamı', 'iş kadını'), ('SÖZCÜ', 'SÖZCÜ'), ('MECLIS ÜYESI', 'MECLIS ÜYESI'), ('onun', 'o'), ('baba', 'anne'), ('kongre üyesi', 'kongre üyesi'), ('IĞDIŞ EDILMIŞ', 'KISRAK'), ('amca dayı', 'hala'), ('Eski Kız Arkadaşı', 'Eski Erkek Arkadaş'), ('OĞUL', 'KIZ EVLAT'), ('OĞULLARI', 'KIZ ÇOCUKLARI'), ('Manastır', 'Manastır'), ('o', 'o'), ('Beyler', 'Hanımlar'), ('TESTOSTERON', 'ESTROJEN'), ('Oğul', 'Kız Evlat'), ('KRAL', 'KRALIÇE'), ('KATOLIK_RAHIP', 'RAHIBE'), ('oğulları', 'kız çocukları'), ('okul çocuğu', 'okul kızı')}
# In English-->  [['prince', 'princess'], ['CONGRESS MEMBER', 'CONGRESS MEMBER'], ['GRANDSON', 'GRANDDAUGHTER'], ['HE', 'HE'], ['Male', 'Female'], ['monastery', 'monastery'], ['Brother', 'Brother'], ['UNCLE', 'STILL'], ['Her', 'HE'], ['councilor', 'councilor'], ['men', 'Woman'], ['GRANDCHILDREN', 'GRANDCHILDREN'], ['man', 'woman'], ['Business man', 'Business woman'], ['king', 'queen'], ['brotherhood', 'sorority'], ['Member of Parliament', 'Member of Parliament'], ['dudes', 'girls'], ['BROTHER', 'BROTHER'], ['colt', 'mare'], ['Grandfather', 'Grandmother'], ['itself', 'self'], ['testosterone', 'estrogen'], ['Catholic Priest', 'Nun'], ['FRIENDS', 'GIRLS'], ['grandson', 'granddaughter'], ['testosterone', 'Estrogen'], ['boys', 'girls'], ['Twin sister', 'Twin sister'], ['Boys', 'Girls'], ['guys', 'ladies'], ['GRANDFATHER', 'GRANDMOTHER'], ['nephew', 'nephew'], ['minister', 'minister'], ['Gentleman', 'Woman'], ['Itself', 'Self'], ['MATE', 'GRANDMOTHER'], ['Fathers', "Mom's"], ['prostate cancer', 'ovarian cancer'], ['spokesman', 'spokesman'], ['grandfather', 'grandmother'], ['brother   ', 'brother'], ['Nephew', 'Nephew'], ['Siblings', 'Sisters'], ['PROSTATE CANCER', 'Ovarian cancer'], ['GRANDFATHER', 'GRANDMOTHER'], ['FATHER', 'MOM'], ['fathers', "mom's"], ['spouses', 'husbands'], ['kings', 'queens'], ['catholic priest', 'nun'], ['Boy', 'Girl'], ['Grandfather', 'grandmother'], ['MEN', 'WOMAN'], ['School boy', 'School girl'], ['KINGS', 'QUEENS'], ['spouses', 'husbands'], ['grandfather', 'grandmother'], ['son', 'daughter'], ['dudes', 'Girls'], ['PRINCE', 'PRINCESS'], ['kings', 'queens'], ['Prince', 'Princess'], ['Minister', 'Minister'], ['PATERNITY', 'MOTHERHOOD'], ['ex girlfriend', 'ex boyfriend'], ['siblings', 'sisters'], ['BOYS', 'GIRLS'], ['GENTLEMAN', 'WOMAN'], ['EX GIRLFRIEND', 'EX BOYFRIEND'], ['mate', 'grandmother'], ['Grandson', 'Granddaughter'], ['BROTHERHOOD', 'DORMITORY FOR GIRLS'], ['TWIN SISTER', 'TWIN SISTER'], ['sons', 'Daughters'], ['gentleman', 'woman'], ['Man', 'Woman'], ['Paternity', 'Motherhood'], ['spokesman', 'spokesman'], ['Colt', 'Mare'], ['FATHERS', "MOM'S"], ['boy', 'girl'], ['WIFE', 'Husbands'], ['MALE', 'FEMALE'], ['Father', 'Mom'], ['MINISTER', 'MINISTER'], ['castrated', 'mare'], ['Brotherhood', "Girls' Dormitory"], ['MONASTERY', 'MONASTERY'], ['Prostate cancer', 'Ovarian Cancer'], ['NEPHEW', 'NEPHEW'], ['Twin sister', 'Twin sister'], ['Grandchildren', 'Grandchildren'], ['SIBLINGS', 'SISTERS'], ['COLT', 'MARE'], ['men', 'woman'], ['BUSINESS MAN', 'BUSINESS WOMAN'], ['My friend', 'Grandmother'], ['Castrated', 'Mare'], ['King', 'Queen'], ['MAN', 'WOMAN'], ['HER', 'HE'], ['grandchildren', 'grandchildren'], ['Uncle', 'still'], ['Congressman', 'Congressman'], ['SCHOOL BOY', 'SCHOOL GIRL'], ['gents', 'WOMEN'], ['paternity', 'motherhood'], ['male', 'female'], ['BOY', 'GIRL'], ['ITSELF', 'SELF'], ['business man', 'business woman'], ['SPOKESMAN', 'SPOKESMAN'], ['MEMBER OF ASSEMBLY', 'MEMBER OF ASSEMBLY'], ['her', 'He'], ['father', 'mom'], ['congressman', 'congressman'], ['castrated', 'MARE'], ['uncle', 'still'], ['Ex-Girlfriend', 'Ex boyfriend'], ['SON', 'DAUGHTER'], ['SONS', 'DAUGHTERS'], ['Monastery', 'Monastery'], ['He', 'He'], ['gentlemen', 'ladies'], ['TESTOSTERONE', 'ESTROGEN'], ['Son', 'Daughter'], ['KING', 'QUEEN'], ['CATHOLIC_PRIEST', 'NUN'], ['sons', 'Daughters'], ['school boy', 'school girl']]

# %% [markdown]
# #### Check the gender bias

# %%
sp_debiased = []

for word in profession_words_turkish:
  sim = get_embed(word)
  if not isinstance(sim, int):
    sp_debiased.append((sim.dot(v_gender), word))

sp_debiased = sorted(sp_debiased)

# %%
he_words = get_translation([item[1] for item in sp_debiased[0:20]], 'tr', 'en')
she_words = get_translation([item[1] for item in sp_debiased[-20:]], 'tr', 'en')

he_words_debiased = []
for item1, item2 in zip(he_words, sp_debiased[0:20]):
  he_words_debiased.append((item2[0], item1))

she_words_debiased = []
for item1, item2 in zip(she_words, sp_debiased[-20:]):
  she_words_debiased.append((item2[0], item1))

# %% [markdown]
# ### Plots for Gender Debiased Algorithms
#
# Google Translator is used to convert turkish words back to english (for representation purposes)

# %%
he_words_debiased, she_words_debiased
# Out:
# ([(-0.29945907, 'captain'),
#   (-0.2879914, 'footballer'),
#   (-0.2614024, 'goalkeeper'),
#   (-0.24645618, 'expert'),
#   (-0.21463771, 'comic'),
#   (-0.21098106, 'barman'),
#   (-0.20780537, 'priest'),
#   (-0.20780537, 'priest'),
#   (-0.19889262, 'drummer'),
#   (-0.19470145, 'baron'),
#   (-0.19191067, 'professor'),
#   (-0.18656872, 'waiter'),
#   (-0.18099487, 'Barber'),
#   (-0.175312, 'priest'),
#   (-0.17257342, 'guitarist'),
#   (-0.16289665, 'publisher'),
#   (-0.15218309, 'commander'),
#   (-0.15168205, 'Wizard'),
#   (-0.15114151, 'boxer'),
#   (-0.14891368, 'carpenter')],
#  [(0.047530815, 'servant'),
#   (0.05250428, 'protection'),
#   (0.056984767, 'dermatologist'),
#   (0.060612477, 'pharmacist'),
#   (0.060612477, 'pharmacist'),
#   (0.06748658, 'therapist'),
#   (0.06789114, 'nanny'),
#   (0.06938549, 'sociologist'),
#   (0.07479843, 'supporter'),
#   (0.07531645, 'ranger'),
#   (0.076362394, 'nurse'),
#   (0.084616005, 'ballerina'),
#   (0.085496806, 'psychologist'),
#   (0.104432896, 'whore'),
#   (0.10572225, 'socialite'),
#   (0.11059825, 'entrepreneur'),
#   (0.12205033, 'stylist'),
#   (0.14444123, 'actress'),
#   (0.1684247, 'laborer'),
#   (0.16878308, 'hot')])

# %%
plot_words_extreme(he_words_debiased, she_words_debiased, 40, x_title='Word Extremes', y_title='Similarity', 
title='Gender Debias In Profession')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="25a8c832-a847-4eb0-a5a0-a870bcae05fd" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25a8c832-a847-4eb0-a5a0-a870bcae05fd")) {                    Plotly.newPlot(                        "25a8c832-a847-4eb0-a5a0-a870bcae05fd",                        [{"mode":"markers+text","name":"Markers and Text","text":["captain","footballer","goalkeeper","expert","comic","barman","priest","priest","drummer","baron","professor","waiter","Barber","priest","guitarist","publisher","commander","Wizard","boxer","carpenter","servant","protection","dermatologist","pharmacist","pharmacist","therapist","nanny","sociologist","supporter","ranger","nurse","ballerina","psychologist","whore","socialite","entrepreneur","stylist","actress","laborer","hot"],"textposition":"bottom center","x":[-1.0,-0.9487179487179487,-0.8974358974358975,-0.8461538461538461,-0.7948717948717949,-0.7435897435897436,-0.6923076923076923,-0.641025641025641,-0.5897435897435898,-0.5384615384615385,-0.4871794871794872,-0.4358974358974359,-0.3846153846153846,-0.33333333333333337,-0.28205128205128205,-0.23076923076923084,-0.17948717948717952,-0.1282051282051282,-0.07692307692307698,-0.02564102564102566,0.02564102564102555,0.07692307692307687,0.1282051282051282,0.17948717948717952,0.23076923076923084,0.28205128205128194,0.33333333333333326,0.3846153846153846,0.4358974358974359,0.4871794871794872,0.5384615384615383,0.5897435897435896,0.641025641025641,0.6923076923076923,0.7435897435897436,0.7948717948717947,0.846153846153846,0.8974358974358974,0.9487179487179487,1.0],"y":[-0.2994590699672699,-0.28799140453338623,-0.2614023983478546,-0.24645617604255676,-0.21463771164417267,-0.21098105609416962,-0.20780536532402039,-0.20780536532402039,-0.19889262318611145,-0.1947014480829239,-0.19191066920757294,-0.1865687221288681,-0.18099486827850342,-0.17531199753284454,-0.17257341742515564,-0.16289664804935455,-0.15218308568000793,-0.151682049036026,-0.15114150941371918,-0.1489136815071106,0.04753081500530243,0.0525042787194252,0.05698476731777191,0.060612477362155914,0.060612477362155914,0.06748657673597336,0.06789114326238632,0.06938549131155014,0.07479842752218246,0.07531645148992538,0.07636239379644394,0.08461600542068481,0.08549680560827255,0.10443289577960968,0.10572224855422974,0.11059825122356415,0.12205033004283905,0.14444123208522797,0.16842469573020935,0.16878308355808258],"type":"scatter"}],                        {"height":1000,"title":{"text":"Gender Debias In Profession","x":0.5},"width":1000,"xaxis":{"title":{"text":"Word Extremes"}},"yaxis":{"title":{"text":"Similarity"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""}, ...

# %% [markdown]
# ![tr_debiased_google.png](data:image/png;base64,...)

# %% [markdown]
# #### Zoomed In - Male Quadrant
# ![tr_debiased_male_google.png](data:image/png;base64,...)

# %% [markdown]
# ### Zoomed In - Female Quadrant
# ![tr_debiased_female_google.png.png](data:image/png;base64,...)

# %%
he_words1, she_words1
# Out:
# ([(-0.29945907, 'captain'),
#   (-0.2879914, 'footballer'),
#   (-0.2614024, 'goalkeeper'),
#   (-0.24645618, 'expert'),
#   (-0.21463771, 'comic'),
#   (-0.21098106, 'barman'),
#   (-0.20780537, 'priest'),
#   (-0.20780537, 'priest'),
#   (-0.19889262, 'drummer'),
#   (-0.19470145, 'baron'),
#   (-0.19191067, 'professor'),
#   (-0.18656872, 'waiter'),
#   (-0.18099487, 'Barber'),
#   (-0.175312, 'priest'),
#   (-0.17257342, 'guitarist'),
#   (-0.16289665, 'publisher'),
#   (-0.15218309, 'commander'),
#   (-0.15168205, 'Wizard'),
#   (-0.15114151, 'boxer'),
#   (-0.14891368, 'carpenter')],
#  [(0.047530815, 'servant'),
#   (0.05250428, 'protection'),
#   (0.056984767, 'dermatologist'),
#   (0.060612477, 'pharmacist'),
#   (0.060612477, 'pharmacist'),
#   (0.06748658, 'therapist'),
#   (0.06789114, 'nanny'),
#   (0.06938549, 'sociologist'),
#   (0.07479843, 'supporter'),
#   (0.07531645, 'ranger'),
#   (0.076362394, 'nurse'),
#   (0.084616005, 'ballerina'),
#   (0.085496806, 'psychologist'),
#   (0.104432896, 'whore'),
#   (0.10572225, 'socialite'),
#   (0.11059825, 'entrepreneur'),
#   (0.12205033, 'stylist'),
#   (0.14444123, 'actress'),
#   (0.1684247, 'laborer'),
#   (0.16878308, 'hot')])

# %% [markdown]
# ### Obeservations
#
# We can see that the debiasing method is somewhat effective here. We have also observed that the google translation is quite literal so we tried getting the translation for Definitional, Equalize and Gender Specific words from Lingvanex which seems to give better translation for turkish words.

# %% [markdown]
# ### Translate Definitional, Equalize and Gender Specific words in Turkish Language using Lingvanex
#
# Here Lingvanex Translator is used to translate Definitional, Equalize and Gender Specific words in Turkish Language in order to make the embeddings available to the debiasing algorithms. We choose this translator as an alternative to google's translator, also recommended by google on top results.
#
# We manually translated Definitional, Equalize and Gender specific words.
#
# Link:- https://lingvanex.com/demo/

# %%
# words used to identify the gender subspace
with open('./data/definitional_pairs_turkish.json', "r") as f:
    defs = json.load(f)
print(len(defs), defs)

# Equalize pairs ensure that neutral words are equidistant from both extremes 
with open('./data/equalize_pairs_turkish.json', "r") as f:
    equalize_pairs = json.load(f)
print(equalize_pairs)

# words where gender specificity is desired
with open('./data/gender_specific_seed_turkish.json', "r") as f:
    gender_specific_words = json.load(f)
print("gender specific", len(gender_specific_words), gender_specific_words[:10])
# Out:
# 7 [['kadını', 'adam'], ['kız', 'oğlan'], ['anne', 'baba'], ['kızı', 'oğul'], ['kadını', 'erkek'], ['onu', 'onun'], ['Maryam', 'Yahya']]
# [['sözcü', 'sözcüsü'], ['rahip', 'rahibe'], ['Baba', 'Anne'], ['Erkekler', 'kadını'], ['meclis üyesi', 'meclis üyesi'], ['dede', 'büyükanne'], ['prostat kanseri', 'yumurtalık kanseri'], ['testosteron', 'östrojen'], ['amca', 'teyze'], ['eşleri', 'kocalar'], ['Büyükbaba', 'Büyükanne'], ['oğlan', 'kız'], ['çocuklar', 'kızlar'], ['kardeş', 'kız kardeş'], ['kardeşler', 'kız kardeşler'], ['işadamı', 'iş kadını'], ['colt', 'kısrak'], ['dostlar', 'gals'], ['babalık', 'annelik'], ['babalar', 'anneler'], ['dostum', 'büyükanne'], ['beyefendi', 'bayan'], ['beyler', 'bayanlar'], ['dede', 'büyükanne'], ['onun', 'onu'], ['kral', 'kraliçe'], ['krallar', 'kraliçeler'], ['erkek', 'kadını'], ['erkekler', 'dişiler'], ['adam', 'kadını'], ['erkekler', 'kadınlar'], ['yeğen', 'yeğen'], ['prens', 'prenses'], ['okul çocuğu', 'kız öğrenci'], ['oğul', 'kızı'], ['oğulları', 'kızları']]
# gender specific 187 ['oyuncu', 'aktrisler', 'teyze', 'teyzeler', 'bekar', 'balerin', 'berber dükkanı', 'baritone', 'sakal', 'beau']

# %%
debias_embeddings(E, gender_specific_words, defs, equalize_pairs)
# Out:
# Pairs dropped:  6
# {('babalar', 'anneler'), ('colt', 'kısrak'), ('oğlan', 'kız'), ('KARDEŞLER', 'KIZ KARDEŞLER'), ('COLT', 'KISRAK'), ('OĞUL', 'KIZI'), ('OĞLAN', 'KIZ'), ('Oğulları', 'Kızları'), ('Babalık', 'Annelik'), ('Amca', 'Teyze'), ('Krallar', 'Kraliçeler'), ('Testosteron', 'Östrojen'), ('kardeş', 'kız kardeş'), ('IŞADAMI', 'IŞ KADINI'), ('çocuklar', 'kızlar'), ('onun', 'onu'), ('OĞULLARI', 'KIZLARI'), ('BEYLER', 'BAYANLAR'), ('OKUL ÇOCUĞU', 'KIZ ÖĞRENCI'), ('DOSTUM', 'BÜYÜKANNE'), ('Eşleri', 'Kocalar'), ('Kral', 'Kraliçe'), ('amca', 'teyze'), ('adam', 'kadını'), ('Colt', 'Kısrak'), ('Işadamı', 'Iş Kadını'), ('Erkekler', 'Kadınlar'), ('EŞLERI', 'KOCALAR'), ('Adam', 'Kadını'), ('ERKEKLER', 'KADINLAR'), ('Erkekler', 'Kadını'), ('Prens', 'Prenses'), ('Oğul', 'Kızı'), ('BABA', 'ANNE'), ('ÇOCUKLAR', 'KIZLAR'), ('rahip', 'rahibe'), ('Dede', 'Büyükanne'), ('Beyefendi', 'Bayan'), ('yeğen', 'yeğen'), ('Okul Çocuğu', 'Kız Öğrenci'), ('krallar', 'kraliçeler'), ('Prostat Kanseri', 'Yumurtalık Kanseri'), ('Büyükbaba', 'Büyükanne'), ('beyefendi', 'bayan'), ('Onun', 'Onu'), ('Kardeş', 'Kız Kardeş'), ('ADAM', 'KADINI'), ('Yeğen', 'Yeğen'), ('testosteron', 'östrojen'), ('YEĞEN', 'YEĞEN'), ('kardeşler', 'kız kardeşler'), ('KARDEŞ', 'KIZ KARDEŞ'), ('Oğlan', 'Kız'), ('DEDE', 'BÜYÜKANNE'), ('MECLIS ÜYESI', 'MECLIS ÜYESI'), ('BABALAR', 'ANNELER'), ('TESTOSTERON', 'ÖSTROJEN'), ('kral', 'kraliçe'), ('dostlar', 'gals'), ('oğul', 'kızı'), ('prostat kanseri', 'yumurtalık kanseri'), ('baba', 'anne'), ('Çocuklar', 'Kızlar'), ('DOSTLAR', 'GALS'), ('beyler', 'bayanlar'), ('AMCA', 'TEYZE'), ('erkek', 'kadını'), ('Sözcü', 'Sözcüsü'), ('Meclis Üyesi', 'Meclis Üyesi'), ('Erkekler', 'Dişiler'), ('ERKEKLER', 'DIŞILER'), ('Dostlar', 'Gals'), ('işadamı', 'iş kadını'), ('sözcü', 'sözcüsü'), ('oğulları', 'kızları'), ('büyükbaba', 'büyükanne'), ('BEYEFENDI', 'BAYAN'), ('KRAL', 'KRALIÇE'), ('KRALLAR', 'KRALIÇELER'), ('babalık', 'annelik'), ('dostum', 'büyükanne'), ('BÜYÜKBABA', 'BÜYÜKANNE'), ('meclis üyesi', 'meclis üyesi'), ('eşleri', 'kocalar'), ('erkekler', 'dişiler'), ('PROSTAT KANSERI', 'YUMURTALIK KANSERI'), ('Beyler', 'Bayanlar'), ('erkekler', 'kadınlar'), ('Kardeşler', 'Kız Kardeşler'), ('Erkek', 'Kadını'), ('Baba', 'Anne'), ('Babalar', 'Anneler'), ('ERKEKLER', 'KADINI'), ('ONUN', 'ONU'), ('prens', 'prenses'), ('SÖZCÜ', 'SÖZCÜSÜ'), ('Dostum', 'Büyükanne'), ('ERKEK', 'KADINI'), ('Rahip', 'Rahibe'), ('okul çocuğu', 'kız öğrenci'), ('dede', 'büyükanne'), ('erkekler', 'kadını'), ('RAHIP', 'RAHIBE'), ('PRENS', 'PRENSES'), ('BABALIK', 'ANNELIK')}
# In English-->  [['fathers', "mom's"], ['colt', 'mare'], ['boy', 'girl'], ['SIBLINGS', 'SISTERS'], ['COLT', 'MARE'], ['SON', 'daughter'], ['BOY', 'GIRL'], ['sons', 'daughters'], ['Paternity', 'Motherhood'], ['Uncle', 'Auntie'], ['kings', 'queens'], ['testosterone', 'Estrogen'], ['brother', 'sister'], ['BUSINESS MAN', 'BUSINESS WOMAN'], ['kids', 'girls'], ['her', 'him-her-it'], ['SONS', 'Daughters'], ['gents', 'LADIES'], ['SCHOOL BOY', 'SCHOOLGIRL'], ['MATE', 'GRANDMOTHER'], ['wives', 'husbands'], ['King', 'Queen'], ['uncle', 'auntie'], ['man', 'woman'], ['colt', 'Mare'], ['Business man', 'Business woman'], ['men', 'females'], ['Wives', 'Husbands'], ['Man', 'Woman'], ['MEN', 'WOMAN'], ['Prince', 'Princess'], ['Son', 'Daughter'], ['FATHER', 'MOM'], ['CHILDREN', 'GIRLS'], ['priest', 'nun'], ['Grandfather', 'Grandmother'], ['Gentleman', 'Woman'], ['nephew', 'nephew'], ['School boy', 'Schoolgirl'], ['kings', 'queens'], ['Prostate cancer', 'Ovarian Cancer'], ['Grandfather', 'Grandmother'], ['gentleman', 'Lady'], ['Her', 'Him-her-it'], ['Brother', 'Sister'], ['MAN', 'WOMAN'], ['Nephew', 'Nephew'], ['testosterone', 'estrogen'], ['NEPHEW', 'NEPHEW'], ['siblings', 'sisters'], ['BROTHER', 'SISTER'], ['Boy', 'Girl'], ['GRANDFATHER', 'GRANDMOTHER'], ['MEMBER OF ASSEMBLY', 'MEMBER OF ASSEMBLY'], ['FATHERS', "MOM'S"], ['TESTOSTERONE', 'ESTROGEN'], ['king', 'queen'], ['friends', 'gals'], ['son', 'daughter'], ['prostate cancer', 'ovarian cancer'], ['father', 'mom'], ['children', 'Girls'], ['FRIENDS', 'GALS'], ['guys', 'ladies'], ['UNCLE', 'AUNTIE'], ['male', 'woman'], ['spokesman', 'spokesperson'], ['Member of Parliament', 'Member of Parliament'], ['Friends', 'gals'], ['business man', 'business woman'], ['spokesman', 'spokesperson'], ['sons', 'daughters'], ['grandfather', 'grandmother'], ['GENTLEMAN', 'LADY'], ['KING', 'QUEEN'], ['KINGS', 'QUEENS'], ['paternity', 'motherhood'], ['mate', 'grandmother'], ['GRANDFATHER', 'GRANDMOTHER'], ['councilor', 'councilor'], ['wives', 'husbands'], ['men', 'woman'], ['PROSTATE CANCER', 'Ovarian cancer'], ['gentlemen', 'ladies'], ['Siblings', 'Sisters'], ['Male', 'Woman'], ['Father', 'Mom'], ['Fathers', "Mom's"], ['HER', 'HIM-HER-IT'], ['prince', 'princess'], ['SPOKESMAN', 'SPEAKER'], ['My friend', 'Grandmother'], ['MALE', 'WOMAN'], ['Priest', 'Nun'], ['school boy', 'schoolgirl'], ['grandfather', 'grandmother'], ['PRIEST', 'NUN'], ['PRINCE', 'PRINCESS'], ['PATERNITY', 'MOTHERHOOD']]

# %% [markdown]
# #### Check the gender bias

# %%
sp_debiased = []

for word in profession_words_turkish:
  sim = get_embed(word)
  if not isinstance(sim, int):
    sp_debiased.append((sim.dot(v_gender), word))

sp_debiased = sorted(sp_debiased)

she_words = get_translation([item[1] for item in sp_debiased[-20:]], 'tr', 'en')
he_words = get_translation([item[1] for item in sp_debiased[:20]], 'tr', 'en')

she_words_debiased = []
for item1, item2 in zip(she_words, sp_debiased[-20:]):
  she_words_debiased.append((item2[0], item1))

he_words_debiased = []
for item1, item2 in zip(he_words, sp_debiased[:20]):
  he_words_debiased.append((item2[0], item1))

# %%
he_words_debiased,she_words_debiased
# Out:
# ([(-0.45006344, 'priest'),
#   (-0.263791, 'footballer'),
#   (-0.2390083, 'captain'),
#   (-0.2312463, 'father'),
#   (-0.2296654, 'professor'),
#   (-0.21737923, 'comic'),
#   (-0.20125966, 'expert'),
#   (-0.20003894, 'journalist'),
#   (-0.19536693, 'goalkeeper'),
#   (-0.19249226, 'author'),
#   (-0.19249226, 'author'),
#   (-0.19126175, 'waiter'),
#   (-0.18465729, 'youth'),
#   (-0.17525657, 'doctor'),
#   (-0.17525657, 'doctor'),
#   (-0.17525657, 'doctor'),
#   (-0.16673878, 'minister'),
#   (-0.16363634, 'barman'),
#   (-0.15887696, 'worker'),
#   (-0.15887696, 'worker')],
#  [(0.021105919, 'forerunner'),
#   (0.025955787, 'steward'),
#   (0.030769937, 'dermatologist'),
#   (0.03171177, 'stylist'),
#   (0.03469614, 'nanny'),
#   (0.0396954, 'therapist'),
#   (0.04497809, 'performer'),
#   (0.047530815, 'servant'),
#   (0.048436914, 'financier'),
#   (0.050311033, 'laborer'),
#   (0.057338435, 'mediator'),
#   (0.057338435, 'mediator'),
#   (0.06364992, 'servant'),
#   (0.06863441, 'protester'),
#   (0.07084545, 'trumpeter'),
#   (0.072716914, 'collector'),
#   (0.084616005, 'ballerina'),
#   (0.08687512, 'supporter'),
#   (0.09935371, 'ranger'),
#   (0.25368145, 'nun')])

# %% [markdown]
# ### Plots for Gender Debiased Algorithms

# %%
plot_words_extreme(he_words_debiased, she_words_debiased, 40, x_title='Word Extremes', y_title='Similarity', 
title='Gender Debias In Profession')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="16df8bc7-701f-48e0-82ea-076c0e020149" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16df8bc7-701f-48e0-82ea-076c0e020149")) {                    Plotly.newPlot(                        "16df8bc7-701f-48e0-82ea-076c0e020149",                        [{"mode":"markers+text","name":"Markers and Text","text":["priest","footballer","captain","father","professor","comic","expert","journalist","goalkeeper","author","author","waiter","youth","doctor","doctor","doctor","minister","barman","worker","worker","forerunner","steward","dermatologist","stylist","nanny","therapist","performer","servant","financier","laborer","mediator","mediator","servant","protester","trumpeter","collector","ballerina","supporter","ranger","nun"],"textposition":"bottom center","x":[-1.0,-0.9487179487179487,-0.8974358974358975,-0.8461538461538461,-0.7948717948717949,-0.7435897435897436,-0.6923076923076923,-0.641025641025641,-0.5897435897435898,-0.5384615384615385,-0.4871794871794872,-0.4358974358974359,-0.3846153846153846,-0.33333333333333337,-0.28205128205128205,-0.23076923076923084,-0.17948717948717952,-0.1282051282051282,-0.07692307692307698,-0.02564102564102566,0.02564102564102555,0.07692307692307687,0.1282051282051282,0.17948717948717952,0.23076923076923084,0.28205128205128194,0.33333333333333326,0.3846153846153846,0.4358974358974359,0.4871794871794872,0.5384615384615383,0.5897435897435896,0.641025641025641,0.6923076923076923,0.7435897435897436,0.7948717948717947,0.846153846153846,0.8974358974358974,0.9487179487179487,1.0],"y":[-0.45006343722343445,-0.2637909948825836,-0.23900829255580902,-0.23124629259109497,-0.22966539859771729,-0.21737922728061676,-0.20125965774059296,-0.20003893971443176,-0.19536693394184113,-0.1924922615289688,-0.1924922615289688,-0.19126175343990326,-0.1846572905778885,-0.17525656521320343,-0.17525656521320343,-0.17525656521320343,-0.16673877835273743,-0.16363634169101715,-0.1588769555091858,-0.1588769555091858,0.021105919033288956,0.025955786928534508,0.030769936740398407,0.03171176835894585,0.03469613939523697,0.03969540074467659,0.04497808963060379,0.04753081500530243,0.04843691363930702,0.05031103268265724,0.05733843520283699,0.05733843520283699,0.06364992260932922,0.06863441318273544,0.07084544748067856,0.07271691411733627,0.08461600542068481,0.08687511831521988,0.09935370832681656,0.2536814510822296],"type":"scatter"}],                        {"height":1000,"title":{"text":"Gender Debias In Profession","x":0.5},"width":1000,"xaxis":{"title":{"text":"Word Extremes"}},"yaxis":{"title":{"text":"Similarity"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"co ...

# %% [markdown]
# ![tr_debiased_lingvanex.png](data:image/png;base64,...)

# %% [markdown]
# #### Zoomed In - Female Quadrant
# ![newplot.png](data:image/png;base64,...)

# %% [markdown]
# #### Zoomed In - Male Quadrant
# ![tr_debiased_male_lingvanex.png](data:image/png;base64,...)

# %% [markdown]
# ### Observation and Conclusion
#
# After using other translator we are able to debias the gender but not upto the mark so we observe that the debiasing algorithms mentioned in the paper does not perform well on Turkish embeddings.
